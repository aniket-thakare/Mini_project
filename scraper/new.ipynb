# %%
import pandas as pd
import numpy as np
import seaborn as snb

df=pd.read_excel('1mg.xlsx')

df.head()
# Out:
#                PRODUCT NAME   PRICE            REQUIREMENT  \
# 0   Amaryl M  1mg Tablet PR  ₹157.7  Prescription Required
# 1          Amlovas 5 Tablet  ₹43.64  Prescription Required
# 2      Aquazide 12.5 Tablet  ₹10.97  Prescription Required
# 3  Alex-L Cough Syrup Mango    ₹118  Prescription Required
# 4       Aciloc RD 20 Tablet  ₹64.05  Prescription Required
#
#                         AVAILABLITY                       MANUFACTURER  \
# 0             strip of 15 Tablet pr                  Sanofi India  Ltd
# 1               strip of 15 tablets   Macleods Pharmaceuticals Pvt Ltd
# 2               strip of 10 tablets  Sun Pharmaceutical Industries Ltd
# 3  bottle of 100 ml Oral Suspension       Glenmark Pharmaceuticals Ltd
# 4               strip of 15 tablets         Cadila Pharmaceuticals Ltd
#
#                                 CONTAINTS
# 0   Glimepiride (1mg) + Metformin (500mg)
# 1                        Amlodipine (5mg)
# 2            Hydrochlorothiazide (12.5mg)
# ...

# %%
df.shape
# Out:
# (21343, 6)

# %%
print(df['AVAILABLITY'].unique())
# Out:
# ['strip of 15 Tablet pr' 'strip of 15 tablets' 'strip of 10 tablets'
#  'bottle of 100 ml Oral Suspension' 'strip of 30 tablets'
#  'bottle of 100 ml Expectorant' 'box of 100 capsules'
#  'tube of 15 gm Cream' 'bottle of 2.5 ml Nail Lacquer'
#  'strip of 15 tablet sr' 'bottle of 15 ml Oral Suspension'
#  'strip of 3 tablets' 'tube of 5 gm Cream' 'vial of 1 Injection'
#  'bottle of 100 ml Syrup' 'packet of 10 ml Eye Drop' 'strip of 1 Tablet'
#  'strip of 6 tablets' 'bottle of 25 capsule tr' 'tube of 30 gm Cream'
#  'strip of 20 Tablet pr' 'vial of 16 ml Injection' 'strip of 10 capsules'
#  'bottle of 100 ml Oral Solution' 'packet of 1 Kit'
#  'bottle of 15 ml Oral Drops' 'strip of 20 tablets'
#  'strip of 10 soft gelatin capsules' 'box of 100 gm Soap'
#  'strip of 10 Effervescent Tablet' 'bottle of 60 ml Syrup'
#  'packet of 30 rotacaps' 'tube of 15 gm Gel' 'strip of 10 tablet cr'
#  'bottle of 200 ml Syrup' 'strip of 7 tablets' 'strip of 14 tablets'
# ...

# %%
df.isnull().sum()
# Out:
# PRODUCT NAME      0
# PRICE             0
# REQUIREMENT     718
# AVAILABLITY       0
# MANUFACTURER      0
# CONTAINTS         0
# dtype: int64

# %%
df.describe()
# Out:
#            PRODUCT NAME  PRICE            REQUIREMENT          AVAILABLITY  \
# count             21343  21343                  20625                21343
# unique            20970   4647                      1                  452
# top     Antiscab Lotion    ₹65  Prescription Required  strip of 10 tablets
# freq                  4    398                  20625                 9787
#
#                   MANUFACTURER             CONTAINTS
# count                    21343                 21343
# unique                    2974                  3295
# top     Alkem Laboratories Ltd  Azithromycin (500mg)
# freq                       221                   846
